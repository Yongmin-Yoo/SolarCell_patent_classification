# %%
import pandas as pd
from selenium import webdriver
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
urls = []

for j in range(10):
    if j == 0:
        print('Crawling 시작')
    driver = webdriver.Chrome('chromedriver.exe')
    url_page = str(j)
    driver.get(url='https://patents.google.com/?q=((solar+cell))&q=(+H02J3%2f381+)&before=priority:20101231&after=priority:20100101&language=ENGLISH&type=PATENT&num=100&page='+url_page)
    
    driver.implicitly_wait(time_to_wait=5)
    info = driver.find_element_by_xpath('//*[@id="resultsContainer"]')
    contents = info.find_elements_by_tag_name('search-result-item')
    for i in range(len(contents)):
        address = contents[i].find_element_by_tag_name('state-modifier').get_attribute('data-result') # patent/name/en
        url = 'patents.google.com/%s' % address
        urls.append('http://'+url)
    if j == 10:
        print('Crawling 끝')

df = pd.DataFrame(urls,columns=['url'])
df.to_csv('url.csv')
print('crawling한 url주소를 url.csv 라는 이름으로 저장함')
print(len(df))


#df = pd.read_csv('H01L31.csv')
df_list = list(df['url'])
len(df_list)

# %%
#df = pd.read_csv('H01L31.csv')
#df_list = list(df['url'])

title = []
abstract = []
label_all = []
meta_label = []

for k in df_list:
    print(k+' Crawling중입니다.')
    html = urlopen(k)
    bsObject = BeautifulSoup(html,'html.parser')
    
#    print('제목시작')
    if len(bsObject.find_all('title')) == 0:
        title.append('No title')
        print("없음")
    else:  
        for a in bsObject.find_all('title'):
            text = a.get_text()
            print("Title : ",len(text))
            title.append(text)
#    print('제목 끝')
    
#    print('abstract 시작')
    if len(bsObject.find_all('meta',{'name':'description'})) == 0:
        abstract.append('No description')
        print('abstract 없음')
    else:
        for b in bsObject.find_all('meta',{'name':'description'}):
            b = str(b)
            b =b.replace('<meta content="\n','')
            c = b.replace('name="description"/>','')
            print("Abstract : ",len(c))
            abstract.append(c)

#     print('abstract 끝')

title_df = pd.DataFrame(title,columns=['Title'])
abstract_df = pd.DataFrame(abstract,columns=['Abstract'])

patent_crawled_df = pd.concat([title_df,abstract_df],axis=1)

patent_crawled_df.to_csv("Final_H01L_31_crawling.csv")
# Out:
# http://patents.google.com/patent/US9793422B2/en Crawling중입니다.
# Title :  50
# Abstract :  990
# http://patents.google.com/patent/US8686283B2/en Crawling중입니다.
# Title :  81
# Abstract :  304
# http://patents.google.com/patent/US8642881B2/en Crawling중입니다.
# Title :  97
# Abstract :  577
# http://patents.google.com/patent/KR101141578B1/en Crawling중입니다.
# Title :  79
# Abstract :  355
# http://patents.google.com/patent/US8969714B2/en Crawling중입니다.
# Title :  103
# Abstract :  958
# http://patents.google.com/patent/KR20110093046A/en Crawling중입니다.
# Title :  104
# Abstract :  884
# http://patents.google.com/patent/KR20110101698A/en Crawling중입니다.
# Title :  89
# Abstract :  1193
# http://patents.google.com/patent/US9455360B2/en Crawling중입니다.
# Title :  93
# Abstract :  1059
# http://patents.google.com/patent/KR101612133B1/en Crawling중입니다.
# Title :  112
# Abstract :  709
# http://patents.google.com/patent/US20120056290A1/en Crawling중입니다.
# Title :  173
# Abstract :  556
# http://patents.google.com/patent/US20110272015A1/en Crawling중입니다.
# Title :  102
# Abstract :  667
# http://patents.google.com/patent/WO2011158743A1/en Crawling중입니다.
# Title :  188
# Abstract :  449
# http://patents.google.com/patent/KR101176133B1/en Crawling중입니다.
# Title :  131
# Abstract :  789
# http://patents.google.com/patent/KR20120011337A/en Crawling중입니다.
# Title :  88
# Abstract :  749
# http://patents.google.com/patent/US10141466B2/en Crawling중입니다.
# Title :  81
# Abstract :  469
# http://patents.google.com/patent/KR20110124112A/en Crawling중입니다.
# Title :  116
# Abstract :  550
# http://patents.google.com/patent/WO2012008061A1/en Crawling중입니다.
# Title :  124
# Abstract :  898
# http://patents.google.com/patent/KR101115104B1/en Crawling중입니다.
# Title :  88
# Abstract :  610
# http://patents.google.com/patent/US9887312B2/en Crawling중입니다.
# Title :  72
# Abstract :  1236
# http://patents.google.com/patent/CN106057919B/en Crawling중입니다.
# Title :  99
# Abstract :  546
# http://patents.google.com/patent/US10526538B2/en Crawling중입니다.
# Title :  145
# Abstract :  632
# http://patents.google.com/patent/US20140283902A1/en Crawling중입니다.
# Title :  86
# Abstract :  458
# http://patents.google.com/patent/JP2015111721A/en Crawling중입니다.
# Title :  122
# Abstract :  1011
# http://patents.google.com/patent/US20110114171A1/en Crawling중입니다.
# Title :  91
# Abstract :  816
# http://patents.google.com/patent/US10424685B2/en Crawling중입니다.
# Title :  142
# Abstract :  856
# http://patents.google.com/patent/KR100990864B1/en Crawling중입니다.
# Title :  90
# Abstract :  586
# http://patents.google.com/patent/US20130125974A1/en Crawling중입니다.
# Title :  99
# Abstract :  573
# http://patents.google.com/patent/KR20120004174A/en Crawling중입니다.
# Title :  106
# Abstract :  850
# http://patents.google.com/patent/KR101088383B1/en Crawling중입니다.
# Title :  167
# Abstract :  1210
# http://patents.google.com/patent/US20130137209A1/en Crawling중입니다.
# Title :  78
# Abstract :  715
# http://patents.google.com/patent/WO2012065957A2/en Crawling중입니다.
# Title :  137
# Abstract :  723
# http://patents.google.com/patent/KR20120062432A/en Crawling중입니다.
# Title :  91
# Abstract :  893
# http://patents.google.com/patent/KR20120002123A/en Crawling중입니다.
# Title :  75
# Abstract :  709
# http://patents.google.com/patent/US20120107996A1/en Crawling중입니다.
# Title :  147
# Abstract :  568
# http://patents.google.com/patent/US8679868B2/en Crawling중입니다.
# Title :  82
# Abstract :  686
# http://patents.google.com/patent/US8445311B2/en Crawling중입니다.
# Title :  93
# Abstract :  481
# http://patents.google.com/patent/US8252624B2/en Crawling중입니다.
# Title :  121
# Abstract :  569
# http://patents.google.com/patent/AU2011371275B2/en Crawling중입니다.
# Title :  72
# Abstract :  436
# http://patents.google.com/patent/TWI528574B/en Crawling중입니다.
# Title :  98
# abstract 없음
# http://patents.google.com/patent/US9184318B2/en Crawling중입니다.
# Title :  127
# Abstract :  512
# http://patents.google.com/patent/KR20110124532A/en Crawling중입니다.
# Title :  89
# Abstract :  1115
# http://patents.google.com/patent/KR20120026683A/en Crawling중입니다.
# Title :  79
# Abstract :  782
# http://patents.google.com/patent/KR20120003732A/en Crawling중입니다.
# Title :  53
# Abstract :  716
# http://patents.google.com/patent/US10629760B2/en Crawling중입니다.
# Title :  96
# Abstract :  191
# http://patents.google.com/patent/US20110180122A1/en Crawling중입니다.
# Title :  105
# Abstract :  387
# http://patents.google.com/patent/JP2013529378A/en Crawling중입니다.
# Title :  80
# Abstract :  1381
# http://patents.google.com/patent/KR101648440B1/en Crawling중입니다.
# Title :  129
# Abstract :  753
# http://patents.google.com/patent/CN101916787B/en Crawling중입니다.
# Title :  96
# Abstract :  1193
# http://patents.google.com/patent/EP2506313B1/en Crawling중입니다.
# Title :  77
# abstract 없음
# http://patents.google.com/patent/US10181535B2/en Crawling중입니다.
# Title :  98
# Abstract :  624
# http://patents.google.com/patent/JP2012023136A/en Crawling중입니다.
# Title :  96
# Abstract :  926
# http://patents.google.com/patent/KR20110129084A/en Crawling중입니다.
# Title :  91
# Abstract :  795
# http://patents.google.com/patent/US20120012171A1/en Crawling중입니다.
# Title :  148
# Abstract :  696
# http://patents.google.com/patent/KR101089416B1/en Crawling중입니다.
# Title :  88
# Abstract :  741
# http://patents.google.com/patent/US20120012172A1/en Crawling중입니다.
# Title :  148
# Abstract :  740
# http://patents.google.com/patent/JP2012109563A/en Crawling중입니다.
# Title :  76
# Abstract :  667
# http://patents.google.com/patent/KR101063748B1/en Crawling중입니다.
# Title :  125
# Abstract :  1661
# http://patents.google.com/patent/KR20110129228A/en Crawling중입니다.
# Title :  74
# Abstract :  856
# http://patents.google.com/patent/US10340412B2/en Crawling중입니다.
# Title :  51
# Abstract :  699
# http://patents.google.com/patent/KR20110124962A/en Crawling중입니다.
# Title :  131
# Abstract :  774
# http://patents.google.com/patent/US8871618B2/en Crawling중입니다.
# Title :  89
# Abstract :  987
# http://patents.google.com/patent/US20120118364A1/en Crawling중입니다.
# Title :  54
# Abstract :  767
# http://patents.google.com/patent/EP2416370A1/en Crawling중입니다.
# Title :  146
# Abstract :  883
# http://patents.google.com/patent/KR101658677B1/en Crawling중입니다.
# Title :  85
# Abstract :  1238
# http://patents.google.com/patent/KR20120026736A/en Crawling중입니다.
# Title :  108
# Abstract :  909
# http://patents.google.com/patent/JP2012004557A/en Crawling중입니다.
# Title :  110
# Abstract :  551
# http://patents.google.com/patent/US20150303319A1/en Crawling중입니다.
# Title :  100
# Abstract :  875
# http://patents.google.com/patent/KR101127999B1/en Crawling중입니다.
# Title :  124
# Abstract :  723
# http://patents.google.com/patent/KR101134131B1/en Crawling중입니다.
# Title :  111
# Abstract :  1169
# http://patents.google.com/patent/JP2011171746A/en Crawling중입니다.
# Title :  97
# Abstract :  723
# http://patents.google.com/patent/TWI408823B/en Crawling중입니다.
# Title :  121
# Abstract :  855
# http://patents.google.com/patent/US10355159B2/en Crawling중입니다.
# Title :  116
# Abstract :  874
# http://patents.google.com/patent/US20120090676A1/en Crawling중입니다.
# Title :  102
# Abstract :  968
# http://patents.google.com/patent/CN102939662B/en Crawling중입니다.
# Title :  106
# Abstract :  992
# http://patents.google.com/patent/KR101114239B1/en Crawling중입니다.
# Title :  87
# Abstract :  409
# http://patents.google.com/patent/US9087940B2/en Crawling중입니다.
# Title :  114
# Abstract :  2472
# http://patents.google.com/patent/KR20110135621A/en Crawling중입니다.
# Title :  124
# Abstract :  834
# http://patents.google.com/patent/CN102142480A/en Crawling중입니다.
# Title :  96
# Abstract :  1034
# http://patents.google.com/patent/KR20120058088A/en Crawling중입니다.
# Title :  82
# Abstract :  663
# http://patents.google.com/patent/US8927317B2/en Crawling중입니다.
# Title :  164
# Abstract :  1013
# http://patents.google.com/patent/US20110303270A1/en Crawling중입니다.
# Title :  149
# Abstract :  668
# http://patents.google.com/patent/KR20120027652A/en Crawling중입니다.
# Title :  122
# Abstract :  633
# http://patents.google.com/patent/AU2011291158B2/en Crawling중입니다.
# Title :  91
# Abstract :  387
# http://patents.google.com/patent/US20130104976A1/en Crawling중입니다.
# Title :  168
# Abstract :  518
# http://patents.google.com/patent/JP2011171745A/en Crawling중입니다.
# Title :  96
# Abstract :  666
# http://patents.google.com/patent/US20160013335A1/en Crawling중입니다.
# Title :  89
# Abstract :  811
# http://patents.google.com/patent/US8809097B1/en Crawling중입니다.
# Title :  102
# Abstract :  845
# http://patents.google.com/patent/KR20120032194A/en Crawling중입니다.
# Title :  109
# Abstract :  647
# http://patents.google.com/patent/US20130269767A1/en Crawling중입니다.
# Title :  104
# Abstract :  915
# http://patents.google.com/patent/KR20120028061A/en Crawling중입니다.
# Title :  74
# Abstract :  576
# http://patents.google.com/patent/US9406821B2/en Crawling중입니다.
# Title :  106
# Abstract :  549
# http://patents.google.com/patent/JP2012015523A/en Crawling중입니다.
# Title :  96
# Abstract :  1244
# http://patents.google.com/patent/WO2012077401A1/en Crawling중입니다.
# Title :  78
# Abstract :  1052
# http://patents.google.com/patent/KR20120027862A/en Crawling중입니다.
# Title :  91
# Abstract :  634
# http://patents.google.com/patent/KR101138554B1/en Crawling중입니다.
# Title :  88
# Abstract :  724
# http://patents.google.com/patent/WO2011133975A2/en Crawling중입니다.
# Title :  91
# Abstract :  917
# http://patents.google.com/patent/KR20120032193A/en Crawling중입니다.
# Title :  115
# Abstract :  610
# http://patents.google.com/patent/EP2388825B1/en Crawling중입니다.
# Title :  138
# abstract 없음
# http://patents.google.com/patent/KR20120065577A/en Crawling중입니다.
# Title :  83
# Abstract :  495
# http://patents.google.com/patent/KR101098813B1/en Crawling중입니다.
# Title :  52
# Abstract :  696
# http://patents.google.com/patent/KR20110098496A/en Crawling중입니다.
# Title :  90
# Abstract :  490
# http://patents.google.com/patent/WO2012036146A1/en Crawling중입니다.
# Title :  99
# Abstract :  806
# http://patents.google.com/patent/US9065008B2/en Crawling중입니다.
# Title :  131
# Abstract :  936
# http://patents.google.com/patent/CN102386265B/en Crawling중입니다.
# Title :  58
# Abstract :  649
# http://patents.google.com/patent/KR20120033024A/en Crawling중입니다.
# Title :  86
# Abstract :  717
# http://patents.google.com/patent/KR101116857B1/en Crawling중입니다.
# Title :  87
# Abstract :  643
# http://patents.google.com/patent/KR101027829B1/en Crawling중입니다.
# Title :  88
# Abstract :  784
# http://patents.google.com/patent/JP2017143303A/en Crawling중입니다.
# Title :  100
# Abstract :  1019
# http://patents.google.com/patent/US8394650B2/en Crawling중입니다.
# Title :  91
# Abstract :  878
# http://patents.google.com/patent/KR101082950B1/en Crawling중입니다.
# Title :  90
# Abstract :  793
# http://patents.google.com/patent/WO2012017517A1/en Crawling중입니다.
# Title :  53
# Abstract :  596
# http://patents.google.com/patent/KR101165915B1/en Crawling중입니다.
# Title :  75
# Abstract :  952
# http://patents.google.com/patent/WO2012020682A1/en Crawling중입니다.
# Title :  73
# Abstract :  1228
# http://patents.google.com/patent/KR101621564B1/en Crawling중입니다.
# Title :  102
# Abstract :  802
# http://patents.google.com/patent/EP2583315B1/en Crawling중입니다.
# Title :  107
# abstract 없음
# http://patents.google.com/patent/US20130098444A1/en Crawling중입니다.
# Title :  208
# Abstract :  696
# http://patents.google.com/patent/JP6289572B2/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/US9991406B2/en Crawling중입니다.
# Title :  128
# Abstract :  310
# http://patents.google.com/patent/TWI441347B/en Crawling중입니다.
# Title :  49
# abstract 없음
# http://patents.google.com/patent/KR101163337B1/en Crawling중입니다.
# Title :  98
# Abstract :  1052
# http://patents.google.com/patent/JP2012094861A/en Crawling중입니다.
# Title :  110
# Abstract :  1237
# http://patents.google.com/patent/KR101665722B1/en Crawling중입니다.
# Title :  85
# Abstract :  400
# http://patents.google.com/patent/US20130180565A1/en Crawling중입니다.
# Title :  114
# Abstract :  461
# http://patents.google.com/patent/EP2423967A2/en Crawling중입니다.
# Title :  87
# Abstract :  655
# http://patents.google.com/patent/KR20120008338A/en Crawling중입니다.
# Title :  79
# Abstract :  885
# http://patents.google.com/patent/US9196765B2/en Crawling중입니다.
# Title :  65
# Abstract :  283
# http://patents.google.com/patent/WO2011114551A1/en Crawling중입니다.
# Title :  87
# Abstract :  1220
# http://patents.google.com/patent/KR20110111649A/en Crawling중입니다.
# Title :  71
# Abstract :  374
# http://patents.google.com/patent/KR101157555B1/en Crawling중입니다.
# Title :  150
# Abstract :  799
# http://patents.google.com/patent/US20180309013A1/en Crawling중입니다.
# Title :  178
# Abstract :  356
# http://patents.google.com/patent/TWI594451B/en Crawling중입니다.
# Title :  162
# abstract 없음
# http://patents.google.com/patent/JP4980494B2/en Crawling중입니다.
# Title :  87
# abstract 없음
# http://patents.google.com/patent/KR20120041437A/en Crawling중입니다.
# Title :  89
# Abstract :  1081
# http://patents.google.com/patent/KR20130108541A/en Crawling중입니다.
# Title :  137
# Abstract :  837
# http://patents.google.com/patent/US9276163B2/en Crawling중입니다.
# Title :  89
# Abstract :  803
# http://patents.google.com/patent/CN102939667B/en Crawling중입니다.
# Title :  209
# Abstract :  1470
# http://patents.google.com/patent/KR20120035291A/en Crawling중입니다.
# Title :  78
# Abstract :  748
# http://patents.google.com/patent/JP6519820B2/en Crawling중입니다.
# Title :  109
# abstract 없음
# http://patents.google.com/patent/US9142706B2/en Crawling중입니다.
# Title :  74
# Abstract :  835
# http://patents.google.com/patent/JP2013537006A/en Crawling중입니다.
# Title :  104
# Abstract :  847
# http://patents.google.com/patent/US8338211B2/en Crawling중입니다.
# Title :  90
# Abstract :  1176
# http://patents.google.com/patent/US9543456B1/en Crawling중입니다.
# Title :  178
# Abstract :  653
# http://patents.google.com/patent/US20120103388A1/en Crawling중입니다.
# Title :  118
# Abstract :  1006
# http://patents.google.com/patent/CN103038896B/en Crawling중입니다.
# Title :  117
# Abstract :  861
# http://patents.google.com/patent/KR101108245B1/en Crawling중입니다.
# Title :  98
# Abstract :  1047
# http://patents.google.com/patent/US10134940B2/en Crawling중입니다.
# Title :  75
# Abstract :  533
# http://patents.google.com/patent/EP2466650A2/en Crawling중입니다.
# Title :  87
# Abstract :  668
# http://patents.google.com/patent/KR20120036115A/en Crawling중입니다.
# Title :  97
# Abstract :  648
# http://patents.google.com/patent/US8865510B2/en Crawling중입니다.
# Title :  74
# Abstract :  756
# http://patents.google.com/patent/JP5604236B2/en Crawling중입니다.
# Title :  129
# abstract 없음
# http://patents.google.com/patent/US8535969B2/en Crawling중입니다.
# Title :  83
# Abstract :  899
# http://patents.google.com/patent/JP6319854B2/en Crawling중입니다.
# Title :  76
# abstract 없음
# http://patents.google.com/patent/JP2016157929A/en Crawling중입니다.
# Title :  89
# Abstract :  638
# http://patents.google.com/patent/KR101680384B1/en Crawling중입니다.
# Title :  77
# Abstract :  1135
# http://patents.google.com/patent/JP5383723B2/en Crawling중입니다.
# Title :  134
# abstract 없음
# http://patents.google.com/patent/CN105489674B/en Crawling중입니다.
# Title :  107
# Abstract :  775
# http://patents.google.com/patent/US8404511B2/en Crawling중입니다.
# Title :  70
# Abstract :  843
# http://patents.google.com/patent/US20130174899A1/en Crawling중입니다.
# Title :  128
# Abstract :  407
# http://patents.google.com/patent/US8647912B2/en Crawling중입니다.
# Title :  90
# Abstract :  993
# http://patents.google.com/patent/JP6326661B2/en Crawling중입니다.
# Title :  86
# abstract 없음
# http://patents.google.com/patent/CN102237431B/en Crawling중입니다.
# Title :  51
# Abstract :  661
# http://patents.google.com/patent/US20130152999A1/en Crawling중입니다.
# Title :  104
# Abstract :  927
# http://patents.google.com/patent/JP6352964B2/en Crawling중입니다.
# Title :  76
# abstract 없음
# http://patents.google.com/patent/ES2720596T3/en Crawling중입니다.
# Title :  84
# Abstract :  853
# http://patents.google.com/patent/KR20110136386A/en Crawling중입니다.
# Title :  75
# Abstract :  729
# http://patents.google.com/patent/WO2011096338A1/en Crawling중입니다.
# Title :  164
# Abstract :  1231
# http://patents.google.com/patent/KR101626162B1/en Crawling중입니다.
# Title :  90
# Abstract :  930
# http://patents.google.com/patent/US10181540B2/en Crawling중입니다.
# Title :  88
# Abstract :  770
# http://patents.google.com/patent/KR101163154B1/en Crawling중입니다.
# Title :  158
# Abstract :  1537
# http://patents.google.com/patent/KR20120057127A/en Crawling중입니다.
# Title :  124
# Abstract :  797
# http://patents.google.com/patent/KR101502208B1/en Crawling중입니다.
# Title :  116
# Abstract :  1310
# http://patents.google.com/patent/US20110315186A1/en Crawling중입니다.
# Title :  128
# Abstract :  816
# http://patents.google.com/patent/TWI497737B/en Crawling중입니다.
# Title :  82
# abstract 없음
# http://patents.google.com/patent/TWI453938B/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/KR20120035680A/en Crawling중입니다.
# Title :  88
# Abstract :  907
# http://patents.google.com/patent/KR101089992B1/en Crawling중입니다.
# Title :  94
# Abstract :  931
# http://patents.google.com/patent/KR101247815B1/en Crawling중입니다.
# Title :  111
# Abstract :  855
# http://patents.google.com/patent/US20120018733A1/en Crawling중입니다.
# Title :  168
# Abstract :  229
# http://patents.google.com/patent/KR101699315B1/en Crawling중입니다.
# Title :  90
# Abstract :  854
# http://patents.google.com/patent/JP5336539B2/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/US8859933B2/en Crawling중입니다.
# Title :  82
# Abstract :  586
# http://patents.google.com/patent/US20130092219A1/en Crawling중입니다.
# Title :  54
# Abstract :  782
# http://patents.google.com/patent/KR101579321B1/en Crawling중입니다.
# Title :  77
# Abstract :  1154
# http://patents.google.com/patent/KR20120002885A/en Crawling중입니다.
# Title :  146
# Abstract :  718
# http://patents.google.com/patent/US9012256B2/en Crawling중입니다.
# Title :  81
# Abstract :  1358
# http://patents.google.com/patent/JP5706541B2/en Crawling중입니다.
# Title :  101
# abstract 없음
# http://patents.google.com/patent/US20130240027A1/en Crawling중입니다.
# Title :  147
# Abstract :  1190
# http://patents.google.com/patent/KR101130965B1/en Crawling중입니다.
# Title :  89
# Abstract :  906
# http://patents.google.com/patent/KR101089485B1/en Crawling중입니다.
# Title :  88
# Abstract :  744
# http://patents.google.com/patent/US9966481B2/en Crawling중입니다.
# Title :  209
# Abstract :  702
# http://patents.google.com/patent/JP6064177B2/en Crawling중입니다.
# Title :  83
# abstract 없음
# http://patents.google.com/patent/CN102024870B/en Crawling중입니다.
# Title :  111
# Abstract :  511
# http://patents.google.com/patent/US9099607B2/en Crawling중입니다.
# Title :  50
# Abstract :  624
# http://patents.google.com/patent/KR101664504B1/en Crawling중입니다.
# Title :  90
# Abstract :  697
# http://patents.google.com/patent/US20120100665A1/en Crawling중입니다.
# Title :  98
# Abstract :  1074
# http://patents.google.com/patent/US20110259387A1/en Crawling중입니다.
# Title :  77
# Abstract :  616
# http://patents.google.com/patent/US9853178B2/en Crawling중입니다.
# Title :  68
# Abstract :  1008
# http://patents.google.com/patent/US20140137939A1/en Crawling중입니다.
# Title :  93
# Abstract :  659
# http://patents.google.com/patent/JP5232213B2/en Crawling중입니다.
# Title :  157
# abstract 없음
# http://patents.google.com/patent/US9368671B2/en Crawling중입니다.
# Title :  67
# Abstract :  687
# http://patents.google.com/patent/US8828780B2/en Crawling중입니다.
# Title :  267
# Abstract :  839
# http://patents.google.com/patent/DE102010035582B4/en Crawling중입니다.
# Title :  135
# Abstract :  773
# http://patents.google.com/patent/US9202954B2/en Crawling중입니다.
# Title :  93
# Abstract :  129
# http://patents.google.com/patent/CN102971859B/en Crawling중입니다.
# Title :  132
# Abstract :  843
# http://patents.google.com/patent/JP5769723B2/en Crawling중입니다.
# Title :  129
# abstract 없음
# http://patents.google.com/patent/KR20120056352A/en Crawling중입니다.
# Title :  100
# Abstract :  996
# http://patents.google.com/patent/KR101117265B1/en Crawling중입니다.
# Title :  110
# Abstract :  468
# http://patents.google.com/patent/EP2423981B1/en Crawling중입니다.
# Title :  101
# abstract 없음
# http://patents.google.com/patent/KR20120022008A/en Crawling중입니다.
# Title :  76
# Abstract :  938
# http://patents.google.com/patent/TWI542025B/en Crawling중입니다.
# Title :  97
# abstract 없음
# http://patents.google.com/patent/US20110162706A1/en Crawling중입니다.
# Title :  123
# Abstract :  556
# http://patents.google.com/patent/TWI429096B/en Crawling중입니다.
# Title :  91
# abstract 없음
# http://patents.google.com/patent/JP5702116B2/en Crawling중입니다.
# Title :  149
# abstract 없음
# http://patents.google.com/patent/KR20120019936A/en Crawling중입니다.
# Title :  76
# Abstract :  1062
# http://patents.google.com/patent/KR101188486B1/en Crawling중입니다.
# Title :  91
# Abstract :  833
# http://patents.google.com/patent/KR20110121140A/en Crawling중입니다.
# Title :  76
# Abstract :  690
# http://patents.google.com/patent/TWI568008B/en Crawling중입니다.
# Title :  141
# abstract 없음
# http://patents.google.com/patent/US20130125952A1/en Crawling중입니다.
# Title :  107
# Abstract :  931
# http://patents.google.com/patent/US10109512B2/en Crawling중입니다.
# Title :  187
# Abstract :  903
# http://patents.google.com/patent/US9252301B2/en Crawling중입니다.
# Title :  90
# Abstract :  967
# http://patents.google.com/patent/JP5149339B2/en Crawling중입니다.
# Title :  139
# Abstract :  549
# http://patents.google.com/patent/KR20120068226A/en Crawling중입니다.
# Title :  78
# Abstract :  791
# http://patents.google.com/patent/WO2012002288A1/en Crawling중입니다.
# Title :  159
# Abstract :  1010
# http://patents.google.com/patent/TWI604624B/en Crawling중입니다.
# Title :  95
# abstract 없음
# http://patents.google.com/patent/KR101046358B1/en Crawling중입니다.
# Title :  87
# Abstract :  895
# http://patents.google.com/patent/US20110168246A1/en Crawling중입니다.
# Title :  97
# Abstract :  988
# http://patents.google.com/patent/US20120103407A1/en Crawling중입니다.
# Title :  98
# Abstract :  1127
# http://patents.google.com/patent/JPWO2012066848A1/en Crawling중입니다.
# Title :  98
# Abstract :  1127
# http://patents.google.com/patent/US20140048116A1/en Crawling중입니다.
# Title :  154
# Abstract :  677
# http://patents.google.com/patent/US8866003B2/en Crawling중입니다.
# Title :  140
# Abstract :  846
# http://patents.google.com/patent/JP5582638B2/en Crawling중입니다.
# Title :  52
# abstract 없음
# http://patents.google.com/patent/JP5719846B2/en Crawling중입니다.
# Title :  264
# abstract 없음
# http://patents.google.com/patent/US9153503B2/en Crawling중입니다.
# Title :  104
# Abstract :  587
# http://patents.google.com/patent/US10084107B2/en Crawling중입니다.
# Title :  94
# Abstract :  552
# http://patents.google.com/patent/US8962987B2/en Crawling중입니다.
# Title :  123
# Abstract :  539
# http://patents.google.com/patent/US20130087200A1/en Crawling중입니다.
# Title :  116
# Abstract :  831
# http://patents.google.com/patent/KR20120021859A/en Crawling중입니다.
# Title :  92
# Abstract :  580
# http://patents.google.com/patent/US9362015B2/en Crawling중입니다.
# Title :  90
# Abstract :  548
# http://patents.google.com/patent/GB2482597A/en Crawling중입니다.
# Title :  87
# Abstract :  1638
# http://patents.google.com/patent/KR101251020B1/en Crawling중입니다.
# Title :  264
# Abstract :  844
# http://patents.google.com/patent/US9035173B2/en Crawling중입니다.
# Title :  278
# Abstract :  662
# http://patents.google.com/patent/JP5874645B2/en Crawling중입니다.
# Title :  125
# abstract 없음
# http://patents.google.com/patent/CN203179910U/en Crawling중입니다.
# Title :  56
# Abstract :  992
# http://patents.google.com/patent/AU2011269243B2/en Crawling중입니다.
# Title :  75
# Abstract :  171
# http://patents.google.com/patent/US20130213453A1/en Crawling중입니다.
# Title :  124
# Abstract :  587
# http://patents.google.com/patent/KR101135587B1/en Crawling중입니다.
# Title :  90
# Abstract :  1168
# http://patents.google.com/patent/KR101135585B1/en Crawling중입니다.
# Title :  90
# Abstract :  977
# http://patents.google.com/patent/KR101277109B1/en Crawling중입니다.
# Title :  78
# Abstract :  440
# http://patents.google.com/patent/KR20110127540A/en Crawling중입니다.
# Title :  76
# Abstract :  962
# http://patents.google.com/patent/US8735206B2/en Crawling중입니다.
# Title :  81
# Abstract :  823
# http://patents.google.com/patent/WO2011118688A1/en Crawling중입니다.
# Title :  132
# Abstract :  518
# http://patents.google.com/patent/KR101726017B1/en Crawling중입니다.
# Title :  165
# Abstract :  875
# http://patents.google.com/patent/US20120031484A1/en Crawling중입니다.
# Title :  87
# Abstract :  765
# http://patents.google.com/patent/KR20120007385A/en Crawling중입니다.
# Title :  90
# Abstract :  877
# http://patents.google.com/patent/ES2508167T3/en Crawling중입니다.
# Title :  93
# Abstract :  1305
# http://patents.google.com/patent/JP5487295B2/en Crawling중입니다.
# Title :  54
# abstract 없음
# http://patents.google.com/patent/KR101127655B1/en Crawling중입니다.
# Title :  135
# Abstract :  1195
# http://patents.google.com/patent/US8507787B2/en Crawling중입니다.
# Title :  103
# Abstract :  572
# http://patents.google.com/patent/US8927851B2/en Crawling중입니다.
# Title :  103
# Abstract :  383
# http://patents.google.com/patent/US8222129B2/en Crawling중입니다.
# Title :  75
# Abstract :  892
# http://patents.google.com/patent/US20110220190A1/en Crawling중입니다.
# Title :  83
# Abstract :  202
# http://patents.google.com/patent/US20130074903A1/en Crawling중입니다.
# Title :  95
# Abstract :  810
# http://patents.google.com/patent/US20130247963A1/en Crawling중입니다.
# Title :  95
# Abstract :  785
# http://patents.google.com/patent/KR101089587B1/en Crawling중입니다.
# Title :  95
# Abstract :  605
# http://patents.google.com/patent/US9202956B2/en Crawling중입니다.
# Title :  123
# Abstract :  509
# http://patents.google.com/patent/TW201205664A/en Crawling중입니다.
# Title :  99
# Abstract :  560
# http://patents.google.com/patent/KR101289787B1/en Crawling중입니다.
# Title :  126
# Abstract :  469
# http://patents.google.com/patent/CN101976711A/en Crawling중입니다.
# Title :  107
# Abstract :  555
# http://patents.google.com/patent/TWI593126B/en Crawling중입니다.
# Title :  262
# abstract 없음
# http://patents.google.com/patent/CN102714229B/en Crawling중입니다.
# Title :  105
# Abstract :  710
# http://patents.google.com/patent/JP4905595B2/en Crawling중입니다.
# Title :  162
# abstract 없음
# http://patents.google.com/patent/JP5215330B2/en Crawling중입니다.
# Title :  170
# abstract 없음
# http://patents.google.com/patent/CN102844881B/en Crawling중입니다.
# Title :  145
# Abstract :  719
# http://patents.google.com/patent/US20120285503A1/en Crawling중입니다.
# Title :  94
# Abstract :  611
# http://patents.google.com/patent/US9130073B2/en Crawling중입니다.
# Title :  121
# Abstract :  672
# http://patents.google.com/patent/EP2583314B1/en Crawling중입니다.
# Title :  115
# abstract 없음
# http://patents.google.com/patent/KR20120072715A/en Crawling중입니다.
# Title :  96
# Abstract :  716
# http://patents.google.com/patent/KR101167779B1/en Crawling중입니다.
# Title :  184
# Abstract :  563
# http://patents.google.com/patent/KR101113027B1/en Crawling중입니다.
# Title :  88
# Abstract :  1038
# http://patents.google.com/patent/KR20120002122A/en Crawling중입니다.
# Title :  88
# Abstract :  730
# http://patents.google.com/patent/WO2012054368A2/en Crawling중입니다.
# Title :  141
# Abstract :  965
# http://patents.google.com/patent/US8173477B2/en Crawling중입니다.
# Title :  127
# Abstract :  234
# http://patents.google.com/patent/CN102569500B/en Crawling중입니다.
# Title :  78
# Abstract :  967
# http://patents.google.com/patent/JP5247931B2/en Crawling중입니다.
# Title :  85
# Abstract :  1267
# http://patents.google.com/patent/US8703506B2/en Crawling중입니다.
# Title :  121
# Abstract :  878
# http://patents.google.com/patent/KR101094324B1/en Crawling중입니다.
# Title :  119
# Abstract :  762
# http://patents.google.com/patent/US8779281B2/en Crawling중입니다.
# Title :  50
# Abstract :  994
# http://patents.google.com/patent/US8962381B2/en Crawling중입니다.
# Title :  132
# Abstract :  753
# http://patents.google.com/patent/TWI535044B/en Crawling중입니다.
# Title :  91
# abstract 없음
# http://patents.google.com/patent/WO2012040917A1/en Crawling중입니다.
# Title :  106
# Abstract :  1149
# http://patents.google.com/patent/KR20110128445A/en Crawling중입니다.
# Title :  152
# Abstract :  854
# http://patents.google.com/patent/CN102576767B/en Crawling중입니다.
# Title :  170
# Abstract :  1071
# http://patents.google.com/patent/KR101167104B1/en Crawling중입니다.
# Title :  96
# Abstract :  1602
# http://patents.google.com/patent/TWI521722B/en Crawling중입니다.
# Title :  214
# abstract 없음
# http://patents.google.com/patent/KR101131008B1/en Crawling중입니다.
# Title :  76
# Abstract :  832
# http://patents.google.com/patent/KR101163321B1/en Crawling중입니다.
# Title :  75
# Abstract :  763
# http://patents.google.com/patent/CN103026506B/en Crawling중입니다.
# Title :  142
# Abstract :  607
# http://patents.google.com/patent/TWI404586B/en Crawling중입니다.
# Title :  138
# Abstract :  1180
# http://patents.google.com/patent/DE102010026289B4/en Crawling중입니다.
# Title :  71
# Abstract :  1064
# http://patents.google.com/patent/KR101368369B1/en Crawling중입니다.
# Title :  114
# Abstract :  618
# http://patents.google.com/patent/JP5502522B2/en Crawling중입니다.
# Title :  83
# abstract 없음
# http://patents.google.com/patent/CN103354940B/en Crawling중입니다.
# Title :  140
# Abstract :  365
# http://patents.google.com/patent/KR101039149B1/en Crawling중입니다.
# Title :  88
# Abstract :  715
# http://patents.google.com/patent/US20130122632A1/en Crawling중입니다.
# Title :  85
# Abstract :  518
# http://patents.google.com/patent/DE102010044348A1/en Crawling중입니다.
# Title :  174
# Abstract :  575
# http://patents.google.com/patent/JP5342071B2/en Crawling중입니다.
# Title :  54
# Abstract :  1122
# http://patents.google.com/patent/US20130133717A1/en Crawling중입니다.
# Title :  99
# Abstract :  450
# http://patents.google.com/patent/TWI520924B/en Crawling중입니다.
# Title :  194
# abstract 없음
# http://patents.google.com/patent/US8431817B2/en Crawling중입니다.
# Title :  114
# Abstract :  684
# http://patents.google.com/patent/WO2012090640A1/en Crawling중입니다.
# Title :  117
# Abstract :  617
# http://patents.google.com/patent/KR20110111165A/en Crawling중입니다.
# Title :  150
# Abstract :  1622
# http://patents.google.com/patent/EP2442368A2/en Crawling중입니다.
# Title :  93
# Abstract :  480
# http://patents.google.com/patent/KR101113025B1/en Crawling중입니다.
# Title :  88
# Abstract :  949
# http://patents.google.com/patent/KR101251896B1/en Crawling중입니다.
# Title :  85
# Abstract :  1010
# http://patents.google.com/patent/US20110168226A1/en Crawling중입니다.
# Title :  98
# Abstract :  874
# http://patents.google.com/patent/KR101597498B1/en Crawling중입니다.
# Title :  126
# Abstract :  449
# http://patents.google.com/patent/US20120097226A1/en Crawling중입니다.
# Title :  89
# Abstract :  778
# http://patents.google.com/patent/JP2013526027A/en Crawling중입니다.
# Title :  110
# Abstract :  692
# http://patents.google.com/patent/US9112088B2/en Crawling중입니다.
# Title :  130
# Abstract :  814
# http://patents.google.com/patent/US8455293B2/en Crawling중입니다.
# Title :  83
# Abstract :  710
# http://patents.google.com/patent/KR101807873B1/en Crawling중입니다.
# Title :  103
# Abstract :  579
# http://patents.google.com/patent/TWI514600B/en Crawling중입니다.
# Title :  186
# abstract 없음
# http://patents.google.com/patent/US20160133774A1/en Crawling중입니다.
# Title :  94
# Abstract :  489
# http://patents.google.com/patent/US9444003B2/en Crawling중입니다.
# Title :  137
# Abstract :  832
# http://patents.google.com/patent/KR20110120540A/en Crawling중입니다.
# Title :  117
# Abstract :  748
# http://patents.google.com/patent/WO2012018110A1/en Crawling중입니다.
# Title :  82
# Abstract :  743
# http://patents.google.com/patent/US8877540B2/en Crawling중입니다.
# Title :  103
# Abstract :  571
# http://patents.google.com/patent/US9985162B2/en Crawling중입니다.
# Title :  88
# Abstract :  801
# http://patents.google.com/patent/KR101659451B1/en Crawling중입니다.
# Title :  85
# Abstract :  756
# http://patents.google.com/patent/KR101285698B1/en Crawling중입니다.
# Title :  199
# Abstract :  776
# http://patents.google.com/patent/JP5837053B2/en Crawling중입니다.
# Title :  120
# abstract 없음
# http://patents.google.com/patent/US9419158B2/en Crawling중입니다.
# Title :  84
# Abstract :  330
# http://patents.google.com/patent/US20110247687A1/en Crawling중입니다.
# Title :  95
# Abstract :  383
# http://patents.google.com/patent/JP2012009578A/en Crawling중입니다.
# Title :  52
# Abstract :  854
# http://patents.google.com/patent/US20150207018A1/en Crawling중입니다.
# Title :  111
# Abstract :  589
# http://patents.google.com/patent/EP2413368A2/en Crawling중입니다.
# Title :  87
# Abstract :  1059
# http://patents.google.com/patent/KR101186436B1/en Crawling중입니다.
# Title :  76
# Abstract :  522
# http://patents.google.com/patent/US8927854B2/en Crawling중입니다.
# Title :  88
# Abstract :  805
# http://patents.google.com/patent/KR20120065578A/en Crawling중입니다.
# Title :  76
# Abstract :  519
# http://patents.google.com/patent/JP4986087B2/en Crawling중입니다.
# Title :  93
# abstract 없음
# http://patents.google.com/patent/KR101137700B1/en Crawling중입니다.
# Title :  109
# Abstract :  1403
# http://patents.google.com/patent/US20160049535A1/en Crawling중입니다.
# Title :  86
# Abstract :  678
# http://patents.google.com/patent/WO2012081813A1/en Crawling중입니다.
# Title :  98
# Abstract :  1735
# http://patents.google.com/patent/US8148192B2/en Crawling중입니다.
# Title :  108
# Abstract :  293
# http://patents.google.com/patent/KR101039148B1/en Crawling중입니다.
# Title :  88
# Abstract :  678
# http://patents.google.com/patent/KR20120020294A/en Crawling중입니다.
# Title :  106
# Abstract :  759
# http://patents.google.com/patent/US20140109961A1/en Crawling중입니다.
# Title :  101
# Abstract :  1070
# http://patents.google.com/patent/KR101101943B1/en Crawling중입니다.
# Title :  86
# Abstract :  400
# http://patents.google.com/patent/KR20120059361A/en Crawling중입니다.
# Title :  117
# Abstract :  696
# http://patents.google.com/patent/US10566477B2/en Crawling중입니다.
# Title :  137
# Abstract :  816
# http://patents.google.com/patent/KR20110117941A/en Crawling중입니다.
# Title :  65
# Abstract :  1412
# http://patents.google.com/patent/CN102403371A/en Crawling중입니다.
# Title :  81
# Abstract :  569
# http://patents.google.com/patent/US8877545B2/en Crawling중입니다.
# Title :  74
# Abstract :  905
# http://patents.google.com/patent/US9076903B2/en Crawling중입니다.
# Title :  129
# Abstract :  991
# http://patents.google.com/patent/KR20110098125A/en Crawling중입니다.
# Title :  127
# Abstract :  746
# http://patents.google.com/patent/JP5745622B2/en Crawling중입니다.
# Title :  90
# abstract 없음
# http://patents.google.com/patent/EP2439779B1/en Crawling중입니다.
# Title :  178
# abstract 없음
# http://patents.google.com/patent/US8580603B2/en Crawling중입니다.
# Title :  121
# Abstract :  1028
# http://patents.google.com/patent/KR20120006179A/en Crawling중입니다.
# Title :  89
# Abstract :  569
# http://patents.google.com/patent/KR101103894B1/en Crawling중입니다.
# Title :  87
# Abstract :  443
# http://patents.google.com/patent/CN102959722B/en Crawling중입니다.
# Title :  139
# Abstract :  557
# http://patents.google.com/patent/US20110226320A1/en Crawling중입니다.
# Title :  130
# Abstract :  905
# http://patents.google.com/patent/US9520531B2/en Crawling중입니다.
# Title :  105
# Abstract :  664
# http://patents.google.com/patent/JP2013519224A/en Crawling중입니다.
# Title :  200
# Abstract :  226
# http://patents.google.com/patent/US20120085397A1/en Crawling중입니다.
# Title :  54
# Abstract :  875
# http://patents.google.com/patent/TWI431797B/en Crawling중입니다.
# Title :  97
# abstract 없음
# http://patents.google.com/patent/US20140057388A1/en Crawling중입니다.
# Title :  109
# Abstract :  664
# http://patents.google.com/patent/US20140057387A1/en Crawling중입니다.
# Title :  107
# Abstract :  664
# http://patents.google.com/patent/KR20140009988A/en Crawling중입니다.
# Title :  94
# Abstract :  497
# http://patents.google.com/patent/KR101044680B1/en Crawling중입니다.
# Title :  88
# Abstract :  842
# http://patents.google.com/patent/US8440489B2/en Crawling중입니다.
# Title :  74
# Abstract :  572
# http://patents.google.com/patent/JP5608609B2/en Crawling중입니다.
# Title :  101
# abstract 없음
# http://patents.google.com/patent/CN102782860A/en Crawling중입니다.
# Title :  97
# Abstract :  830
# http://patents.google.com/patent/US20130240032A1/en Crawling중입니다.
# Title :  145
# Abstract :  457
# http://patents.google.com/patent/DE102010039563A1/en Crawling중입니다.
# Title :  203
# Abstract :  390
# http://patents.google.com/patent/KR101131218B1/en Crawling중입니다.
# Title :  161
# Abstract :  818
# http://patents.google.com/patent/JP4868079B1/en Crawling중입니다.
# Title :  168
# Abstract :  759
# http://patents.google.com/patent/EP2458649B1/en Crawling중입니다.
# Title :  50
# abstract 없음
# http://patents.google.com/patent/EP2601691A2/en Crawling중입니다.
# Title :  98
# Abstract :  1258
# http://patents.google.com/patent/WO2011118685A1/en Crawling중입니다.
# Title :  83
# Abstract :  930
# http://patents.google.com/patent/WO2012062298A2/en Crawling중입니다.
# Title :  123
# Abstract :  1025
# http://patents.google.com/patent/JP2014506391A/en Crawling중입니다.
# Title :  96
# Abstract :  609
# http://patents.google.com/patent/KR101149768B1/en Crawling중입니다.
# Title :  126
# Abstract :  1577
# http://patents.google.com/patent/US8916412B2/en Crawling중입니다.
# Title :  110
# Abstract :  807
# http://patents.google.com/patent/DE102010062965A1/en Crawling중입니다.
# Title :  212
# Abstract :  420
# http://patents.google.com/patent/CN102893404B/en Crawling중입니다.
# Title :  162
# Abstract :  838
# http://patents.google.com/patent/JP2012060123A/en Crawling중입니다.
# Title :  202
# Abstract :  596
# http://patents.google.com/patent/US9324888B2/en Crawling중입니다.
# Title :  84
# Abstract :  297
# http://patents.google.com/patent/KR20110134211A/en Crawling중입니다.
# Title :  88
# Abstract :  636
# http://patents.google.com/patent/CN103109374A/en Crawling중입니다.
# Title :  88
# Abstract :  797
# http://patents.google.com/patent/CN201780976U/en Crawling중입니다.
# Title :  74
# Abstract :  951
# http://patents.google.com/patent/DE102010054182A1/en Crawling중입니다.
# Title :  268
# Abstract :  709
# http://patents.google.com/patent/KR101147165B1/en Crawling중입니다.
# Title :  190
# Abstract :  662
# http://patents.google.com/patent/US8377739B2/en Crawling중입니다.
# Title :  123
# Abstract :  675
# http://patents.google.com/patent/JP5705971B2/en Crawling중입니다.
# Title :  135
# abstract 없음
# http://patents.google.com/patent/US20120111399A1/en Crawling중입니다.
# Title :  64
# Abstract :  483
# http://patents.google.com/patent/EP2559075B1/en Crawling중입니다.
# Title :  123
# abstract 없음
# http://patents.google.com/patent/US9660132B2/en Crawling중입니다.
# Title :  74
# Abstract :  623
# http://patents.google.com/patent/KR101237847B1/en Crawling중입니다.
# Title :  233
# Abstract :  2307
# http://patents.google.com/patent/KR101142273B1/en Crawling중입니다.
# Title :  136
# Abstract :  960
# http://patents.google.com/patent/JP3169353U/en Crawling중입니다.
# Title :  83
# Abstract :  1092
# http://patents.google.com/patent/CN103339746B/en Crawling중입니다.
# Title :  142
# Abstract :  796
# http://patents.google.com/patent/JP5256268B2/en Crawling중입니다.
# Title :  52
# abstract 없음
# http://patents.google.com/patent/US8592677B2/en Crawling중입니다.
# Title :  123
# Abstract :  391
# http://patents.google.com/patent/CN102130217B/en Crawling중입니다.
# Title :  98
# Abstract :  1027
# http://patents.google.com/patent/KR20120045963A/en Crawling중입니다.
# Title :  124
# Abstract :  1481
# http://patents.google.com/patent/JPWO2012002440A1/en Crawling중입니다.
# Title :  159
# Abstract :  600
# http://patents.google.com/patent/US20110174376A1/en Crawling중입니다.
# Title :  67
# Abstract :  382
# http://patents.google.com/patent/US20130153023A1/en Crawling중입니다.
# Title :  91
# Abstract :  661
# http://patents.google.com/patent/JP2013518426A/en Crawling중입니다.
# Title :  140
# Abstract :  744
# http://patents.google.com/patent/KR101153271B1/en Crawling중입니다.
# Title :  79
# Abstract :  1377
# http://patents.google.com/patent/DE102010001420A1/en Crawling중입니다.
# Title :  79
# Abstract :  187
# http://patents.google.com/patent/CN102971862B/en Crawling중입니다.
# Title :  82
# Abstract :  394
# http://patents.google.com/patent/JP2011142210A/en Crawling중입니다.
# Title :  89
# Abstract :  1266
# http://patents.google.com/patent/JP5608735B2/en Crawling중입니다.
# Title :  115
# abstract 없음
# http://patents.google.com/patent/US20130014819A1/en Crawling중입니다.
# Title :  125
# Abstract :  517
# http://patents.google.com/patent/US20190288147A1/en Crawling중입니다.
# Title :  103
# Abstract :  301
# http://patents.google.com/patent/KR101144068B1/en Crawling중입니다.
# Title :  109
# Abstract :  803
# http://patents.google.com/patent/JP2012099822A/en Crawling중입니다.
# Title :  92
# Abstract :  915
# http://patents.google.com/patent/DE102011081983A1/en Crawling중입니다.
# Title :  90
# Abstract :  1172
# http://patents.google.com/patent/TWI544654B/en Crawling중입니다.
# Title :  136
# abstract 없음
# http://patents.google.com/patent/KR101088046B1/en Crawling중입니다.
# Title :  96
# Abstract :  613
# http://patents.google.com/patent/DE102010024834A1/en Crawling중입니다.
# Title :  209
# Abstract :  1967
# http://patents.google.com/patent/US8790948B2/en Crawling중입니다.
# Title :  77
# Abstract :  769
# http://patents.google.com/patent/KR20120074202A/en Crawling중입니다.
# Title :  79
# Abstract :  589
# http://patents.google.com/patent/KR101130200B1/en Crawling중입니다.
# Title :  52
# Abstract :  424
# http://patents.google.com/patent/JP5970796B2/en Crawling중입니다.
# Title :  181
# abstract 없음
# http://patents.google.com/patent/KR101231430B1/en Crawling중입니다.
# Title :  87
# Abstract :  396
# http://patents.google.com/patent/KR101665139B1/en Crawling중입니다.
# Title :  90
# Abstract :  848
# http://patents.google.com/patent/US20110180131A1/en Crawling중입니다.
# Title :  118
# Abstract :  606
# http://patents.google.com/patent/JP6274677B2/en Crawling중입니다.
# Title :  81
# abstract 없음
# http://patents.google.com/patent/US9109302B2/en Crawling중입니다.
# Title :  99
# Abstract :  582
# http://patents.google.com/patent/JP5723143B2/en Crawling중입니다.
# Title :  131
# abstract 없음
# http://patents.google.com/patent/US8168467B2/en Crawling중입니다.
# Title :  96
# Abstract :  265
# http://patents.google.com/patent/JP5633284B2/en Crawling중입니다.
# Title :  82
# abstract 없음
# http://patents.google.com/patent/WO2011162322A1/en Crawling중입니다.
# Title :  87
# Abstract :  593
# http://patents.google.com/patent/KR20120137361A/en Crawling중입니다.
# Title :  112
# Abstract :  898
# http://patents.google.com/patent/KR101154095B1/en Crawling중입니다.
# Title :  89
# Abstract :  1314
# http://patents.google.com/patent/JP2011233760A/en Crawling중입니다.
# Title :  73
# Abstract :  727
# http://patents.google.com/patent/US20130118576A1/en Crawling중입니다.
# Title :  71
# Abstract :  639
# http://patents.google.com/patent/KR20120063735A/en Crawling중입니다.
# Title :  89
# Abstract :  941
# http://patents.google.com/patent/KR20110123185A/en Crawling중입니다.
# Title :  97
# Abstract :  673
# http://patents.google.com/patent/KR101203116B1/en Crawling중입니다.
# Title :  142
# Abstract :  842
# http://patents.google.com/patent/KR20110136178A/en Crawling중입니다.
# Title :  90
# Abstract :  647
# http://patents.google.com/patent/DE102010028189B4/en Crawling중입니다.
# Title :  59
# Abstract :  1167
# http://patents.google.com/patent/TW201145556A/en Crawling중입니다.
# Title :  127
# Abstract :  535
# http://patents.google.com/patent/US20120024366A1/en Crawling중입니다.
# Title :  105
# Abstract :  422
# http://patents.google.com/patent/JP5665839B2/en Crawling중입니다.
# Title :  92
# abstract 없음
# http://patents.google.com/patent/US20150047696A1/en Crawling중입니다.
# Title :  88
# Abstract :  276
# http://patents.google.com/patent/KR20120068263A/en Crawling중입니다.
# Title :  102
# Abstract :  818
# http://patents.google.com/patent/DE102010033030A1/en Crawling중입니다.
# Title :  264
# Abstract :  475
# http://patents.google.com/patent/US9196782B2/en Crawling중입니다.
# Title :  146
# Abstract :  838
# http://patents.google.com/patent/KR20110081761A/en Crawling중입니다.
# Title :  140
# Abstract :  903
# http://patents.google.com/patent/JP5516063B2/en Crawling중입니다.
# Title :  98
# abstract 없음
# http://patents.google.com/patent/TWI408825B/en Crawling중입니다.
# Title :  129
# Abstract :  665
# http://patents.google.com/patent/US20110269263A1/en Crawling중입니다.
# Title :  150
# Abstract :  576
# http://patents.google.com/patent/KR20120075100A/en Crawling중입니다.
# Title :  84
# Abstract :  762
# http://patents.google.com/patent/US9087938B2/en Crawling중입니다.
# Title :  136
# Abstract :  834
# http://patents.google.com/patent/KR20110107934A/en Crawling중입니다.
# Title :  114
# Abstract :  689
# http://patents.google.com/patent/DE102010061294A1/en Crawling중입니다.
# Title :  224
# Abstract :  604
# http://patents.google.com/patent/DE102010030884A1/en Crawling중입니다.
# Title :  277
# Abstract :  1496
# http://patents.google.com/patent/US8329496B2/en Crawling중입니다.
# Title :  102
# Abstract :  818
# http://patents.google.com/patent/DE102010004497A1/en Crawling중입니다.
# Title :  275
# Abstract :  689
# http://patents.google.com/patent/US8664100B2/en Crawling중입니다.
# Title :  104
# Abstract :  469
# http://patents.google.com/patent/US8723019B2/en Crawling중입니다.
# Title :  87
# Abstract :  495
# http://patents.google.com/patent/DE102010028239A1/en Crawling중입니다.
# Title :  250
# Abstract :  430
# http://patents.google.com/patent/KR101152660B1/en Crawling중입니다.
# Title :  115
# Abstract :  798
# http://patents.google.com/patent/CN102299197B/en Crawling중입니다.
# Title :  99
# Abstract :  1090
# http://patents.google.com/patent/KR20120075099A/en Crawling중입니다.
# Title :  84
# Abstract :  737
# http://patents.google.com/patent/TWI549313B/en Crawling중입니다.
# Title :  158
# abstract 없음
# http://patents.google.com/patent/US8677929B2/en Crawling중입니다.
# Title :  109
# Abstract :  517
# http://patents.google.com/patent/CN102163649B/en Crawling중입니다.
# Title :  74
# Abstract :  1272
# http://patents.google.com/patent/US20120103419A1/en Crawling중입니다.
# Title :  150
# Abstract :  289
# http://patents.google.com/patent/WO2012024647A2/en Crawling중입니다.
# Title :  73
# Abstract :  460
# http://patents.google.com/patent/US9147788B2/en Crawling중입니다.
# Title :  66
# Abstract :  791
# http://patents.google.com/patent/US20120152335A1/en Crawling중입니다.
# Title :  79
# Abstract :  977
# http://patents.google.com/patent/EP2600409A1/en Crawling중입니다.
# Title :  96
# Abstract :  872
# http://patents.google.com/patent/KR20110100374A/en Crawling중입니다.
# Title :  96
# Abstract :  567
# http://patents.google.com/patent/KR20110120543A/en Crawling중입니다.
# Title :  117
# Abstract :  813
# http://patents.google.com/patent/KR20120035407A/en Crawling중입니다.
# Title :  78
# Abstract :  639
# http://patents.google.com/patent/US9214593B2/en Crawling중입니다.
# Title :  88
# Abstract :  886
# http://patents.google.com/patent/US8586129B2/en Crawling중입니다.
# Title :  98
# Abstract :  998
# http://patents.google.com/patent/JP5922072B2/en Crawling중입니다.
# Title :  135
# abstract 없음
# http://patents.google.com/patent/KR20110080591A/en Crawling중입니다.
# Title :  106
# Abstract :  696
# http://patents.google.com/patent/US20110253204A1/en Crawling중입니다.
# Title :  54
# Abstract :  418
# http://patents.google.com/patent/WO2011161010A2/en Crawling중입니다.
# Title :  157
# Abstract :  774
# http://patents.google.com/patent/KR101116235B1/en Crawling중입니다.
# Title :  180
# Abstract :  2423
# http://patents.google.com/patent/KR101110356B1/en Crawling중입니다.
# Title :  139
# Abstract :  565
# http://patents.google.com/patent/US8455756B2/en Crawling중입니다.
# Title :  104
# Abstract :  646
# http://patents.google.com/patent/US20190013430A1/en Crawling중입니다.
# Title :  91
# Abstract :  509
# http://patents.google.com/patent/DE112011102949T5/en Crawling중입니다.
# Title :  97
# Abstract :  800
# http://patents.google.com/patent/EP2657979B1/en Crawling중입니다.
# Title :  83
# abstract 없음
# http://patents.google.com/patent/KR20110129629A/en Crawling중입니다.
# Title :  114
# Abstract :  693
# http://patents.google.com/patent/KR101018672B1/en Crawling중입니다.
# Title :  102
# Abstract :  590
# http://patents.google.com/patent/WO2012069995A2/en Crawling중입니다.
# Title :  155
# Abstract :  323
# http://patents.google.com/patent/US20120090682A1/en Crawling중입니다.
# Title :  87
# Abstract :  950
# http://patents.google.com/patent/KR101097052B1/en Crawling중입니다.
# Title :  80
# Abstract :  750
# http://patents.google.com/patent/JP5882573B2/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/US20120094430A1/en Crawling중입니다.
# Title :  141
# Abstract :  706
# http://patents.google.com/patent/WO2012031649A1/en Crawling중입니다.
# Title :  104
# Abstract :  754
# http://patents.google.com/patent/KR20120029281A/en Crawling중입니다.
# Title :  98
# Abstract :  786
# http://patents.google.com/patent/US20120048376A1/en Crawling중입니다.
# Title :  118
# Abstract :  922
# http://patents.google.com/patent/US8438989B2/en Crawling중입니다.
# Title :  139
# Abstract :  1055
# http://patents.google.com/patent/JP5335140B2/en Crawling중입니다.
# Title :  127
# Abstract :  820
# http://patents.google.com/patent/WO2011158899A1/en Crawling중입니다.
# Title :  73
# Abstract :  852
# http://patents.google.com/patent/TWI455329B/en Crawling중입니다.
# Title :  79
# abstract 없음
# http://patents.google.com/patent/KR20120053289A/en Crawling중입니다.
# Title :  88
# Abstract :  590
# http://patents.google.com/patent/TWI422045B/en Crawling중입니다.
# Title :  99
# abstract 없음
# http://patents.google.com/patent/CN102403214B/en Crawling중입니다.
# Title :  128
# Abstract :  585
# http://patents.google.com/patent/US20110277833A1/en Crawling중입니다.
# Title :  71
# Abstract :  155
# http://patents.google.com/patent/US20180108803A1/en Crawling중입니다.
# Title :  170
# Abstract :  889
# http://patents.google.com/patent/WO2012018199A2/en Crawling중입니다.
# Title :  218
# Abstract :  856
# http://patents.google.com/patent/DE102010028277B4/en Crawling중입니다.
# Title :  187
# Abstract :  716
# http://patents.google.com/patent/US8187963B2/en Crawling중입니다.
# Title :  104
# Abstract :  434
# http://patents.google.com/patent/KR101007743B1/en Crawling중입니다.
# Title :  88
# Abstract :  4422
# http://patents.google.com/patent/US8207013B2/en Crawling중입니다.
# Title :  150
# Abstract :  455
# http://patents.google.com/patent/KR101226201B1/en Crawling중입니다.
# Title :  141
# Abstract :  693
# http://patents.google.com/patent/WO2012005253A1/en Crawling중입니다.
# Title :  185
# Abstract :  772
# http://patents.google.com/patent/US8906732B2/en Crawling중입니다.
# Title :  86
# Abstract :  1026
# http://patents.google.com/patent/US20110290309A1/en Crawling중입니다.
# Title :  92
# Abstract :  1377
# http://patents.google.com/patent/US8569102B2/en Crawling중입니다.
# Title :  169
# Abstract :  521
# http://patents.google.com/patent/KR20110123482A/en Crawling중입니다.
# Title :  111
# Abstract :  809
# ...
# Abstract :  991
# http://patents.google.com/patent/CN104247047B/en Crawling중입니다.
# Title :  88
# Abstract :  635
# http://patents.google.com/patent/KR101929445B1/en Crawling중입니다.
# Title :  90
# Abstract :  457
# http://patents.google.com/patent/EP2823514B1/en Crawling중입니다.
# Title :  95
# abstract 없음
# http://patents.google.com/patent/JP6343608B2/en Crawling중입니다.
# Title :  52
# abstract 없음
# http://patents.google.com/patent/US9349882B2/en Crawling중입니다.
# Title :  136
# Abstract :  1426
# http://patents.google.com/patent/US9082908B2/en Crawling중입니다.
# Title :  50
# Abstract :  899
# http://patents.google.com/patent/US9059357B2/en Crawling중입니다.
# Title :  59
# Abstract :  793
# http://patents.google.com/patent/JP6447926B2/en Crawling중입니다.
# Title :  90
# abstract 없음
# http://patents.google.com/patent/US20150136210A1/en Crawling중입니다.
# Title :  123
# Abstract :  1103
# http://patents.google.com/patent/US8871560B2/en Crawling중입니다.
# Title :  81
# Abstract :  468
# http://patents.google.com/patent/US11031515B2/en Crawling중입니다.
# Title :  122
# Abstract :  802
# http://patents.google.com/patent/US9343602B2/en Crawling중입니다.
# Title :  93
# Abstract :  724
# http://patents.google.com/patent/KR101370554B1/en Crawling중입니다.
# Title :  95
# Abstract :  303
# http://patents.google.com/patent/KR101474487B1/en Crawling중입니다.
# Title :  97
# Abstract :  578
# http://patents.google.com/patent/JP6831964B2/en Crawling중입니다.
# Title :  52
# abstract 없음
# http://patents.google.com/patent/CN103715283B/en Crawling중입니다.
# Title :  92
# Abstract :  905
# http://patents.google.com/patent/KR101436538B1/en Crawling중입니다.
# Title :  97
# Abstract :  523
# http://patents.google.com/patent/JP2015516145A/en Crawling중입니다.
# Title :  115
# Abstract :  201
# http://patents.google.com/patent/KR101414570B1/en Crawling중입니다.
# Title :  128
# Abstract :  1215
# http://patents.google.com/patent/US20140179056A1/en Crawling중입니다.
# Title :  104
# Abstract :  530
# http://patents.google.com/patent/US20130255760A1/en Crawling중입니다.
# Title :  91
# Abstract :  708
# http://patents.google.com/patent/CN104205364B/en Crawling중입니다.
# Title :  91
# Abstract :  693
# http://patents.google.com/patent/US8900664B2/en Crawling중입니다.
# Title :  94
# Abstract :  517
# http://patents.google.com/patent/US9343591B2/en Crawling중입니다.
# Title :  79
# Abstract :  402
# http://patents.google.com/patent/US9564551B2/en Crawling중입니다.
# Title :  108
# Abstract :  590
# http://patents.google.com/patent/US9418844B1/en Crawling중입니다.
# Title :  104
# Abstract :  440
# http://patents.google.com/patent/US20160260850A1/en Crawling중입니다.
# Title :  136
# Abstract :  932
# http://patents.google.com/patent/JP2015525970A/en Crawling중입니다.
# Title :  121
# Abstract :  829
# http://patents.google.com/patent/KR101798967B1/en Crawling중입니다.
# Title :  77
# Abstract :  1979
# http://patents.google.com/patent/US8980681B2/en Crawling중입니다.
# Title :  73
# Abstract :  791
# http://patents.google.com/patent/AU2013272248A1/en Crawling중입니다.
# Title :  146
# Abstract :  810
# http://patents.google.com/patent/US10304972B2/en Crawling중입니다.
# Title :  92
# Abstract :  511
# http://patents.google.com/patent/CN107634108B/en Crawling중입니다.
# Title :  91
# Abstract :  568
# http://patents.google.com/patent/US20140004652A1/en Crawling중입니다.
# Title :  76
# Abstract :  308
# http://patents.google.com/patent/KR101195927B1/en Crawling중입니다.
# Title :  82
# Abstract :  579
# http://patents.google.com/patent/WO2013128901A1/en Crawling중입니다.
# Title :  94
# Abstract :  1019
# http://patents.google.com/patent/US9559246B2/en Crawling중입니다.
# Title :  106
# Abstract :  632
# http://patents.google.com/patent/JP5885829B2/en Crawling중입니다.
# Title :  151
# abstract 없음
# http://patents.google.com/patent/KR101401887B1/en Crawling중입니다.
# Title :  96
# Abstract :  334
# http://patents.google.com/patent/US8680393B2/en Crawling중입니다.
# Title :  61
# Abstract :  416
# http://patents.google.com/patent/KR101289832B1/en Crawling중입니다.
# Title :  85
# Abstract :  806
# http://patents.google.com/patent/JP6383730B2/en Crawling중입니다.
# Title :  83
# abstract 없음
# http://patents.google.com/patent/TWI474488B/en Crawling중입니다.
# Title :  49
# abstract 없음
# http://patents.google.com/patent/KR20140043213A/en Crawling중입니다.
# Title :  78
# Abstract :  392
# http://patents.google.com/patent/KR101381844B1/en Crawling중입니다.
# Title :  88
# Abstract :  1097
# http://patents.google.com/patent/JP6168627B2/en Crawling중입니다.
# Title :  120
# abstract 없음
# http://patents.google.com/patent/US8852990B2/en Crawling중입니다.
# Title :  72
# Abstract :  746
# http://patents.google.com/patent/CN103247715B/en Crawling중입니다.
# Title :  78
# Abstract :  393
# http://patents.google.com/patent/JP2015508573A/en Crawling중입니다.
# Title :  78
# Abstract :  865
# http://patents.google.com/patent/US10069021B2/en Crawling중입니다.
# Title :  151
# Abstract :  677
# http://patents.google.com/patent/EP2654091A2/en Crawling중입니다.
# Title :  81
# Abstract :  781
# http://patents.google.com/patent/US20140116500A1/en Crawling중입니다.
# Title :  141
# Abstract :  634
# http://patents.google.com/patent/CN104620394B/en Crawling중입니다.
# Title :  93
# Abstract :  520
# http://patents.google.com/patent/US9768342B2/en Crawling중입니다.
# Title :  88
# Abstract :  939
# http://patents.google.com/patent/US20130199606A1/en Crawling중입니다.
# Title :  134
# Abstract :  959
# http://patents.google.com/patent/KR101952970B1/en Crawling중입니다.
# Title :  82
# Abstract :  1107
# http://patents.google.com/patent/US20140174505A1/en Crawling중입니다.
# Title :  114
# Abstract :  872
# http://patents.google.com/patent/US20140373339A1/en Crawling중입니다.
# Title :  173
# Abstract :  435
# http://patents.google.com/patent/CN104737306B/en Crawling중입니다.
# Title :  117
# Abstract :  429
# http://patents.google.com/patent/KR101352537B1/en Crawling중입니다.
# Title :  112
# Abstract :  780
# http://patents.google.com/patent/KR101459099B1/en Crawling중입니다.
# Title :  100
# Abstract :  520
# http://patents.google.com/patent/KR101215313B1/en Crawling중입니다.
# Title :  144
# Abstract :  692
# http://patents.google.com/patent/TWI570948B/en Crawling중입니다.
# Title :  94
# abstract 없음
# http://patents.google.com/patent/KR20140078783A/en Crawling중입니다.
# Title :  86
# Abstract :  1357
# http://patents.google.com/patent/US10141459B2/en Crawling중입니다.
# Title :  96
# Abstract :  1087
# http://patents.google.com/patent/CN104488094B/en Crawling중입니다.
# Title :  89
# Abstract :  1124
# http://patents.google.com/patent/JP5963463B2/en Crawling중입니다.
# Title :  192
# abstract 없음
# http://patents.google.com/patent/JP6316824B2/en Crawling중입니다.
# Title :  94
# abstract 없음
# http://patents.google.com/patent/CN102623574A/en Crawling중입니다.
# Title :  144
# Abstract :  1413
# http://patents.google.com/patent/US20160284894A1/en Crawling중입니다.
# Title :  94
# Abstract :  421
# http://patents.google.com/patent/JP6193244B2/en Crawling중입니다.
# Title :  229
# abstract 없음
# http://patents.google.com/patent/US9257284B2/en Crawling중입니다.
# Title :  74
# Abstract :  934
# http://patents.google.com/patent/CN103489939A/en Crawling중입니다.
# Title :  209
# Abstract :  1328
# http://patents.google.com/patent/CN104221126B/en Crawling중입니다.
# Title :  226
# Abstract :  1230
# http://patents.google.com/patent/KR101890282B1/en Crawling중입니다.
# Title :  109
# Abstract :  566
# http://patents.google.com/patent/CN104488088B/en Crawling중입니다.
# Title :  102
# Abstract :  829
# http://patents.google.com/patent/KR20140022508A/en Crawling중입니다.
# Title :  110
# Abstract :  1935
# http://patents.google.com/patent/US9911885B2/en Crawling중입니다.
# Title :  56
# Abstract :  842
# http://patents.google.com/patent/JP6281706B2/en Crawling중입니다.
# Title :  123
# abstract 없음
# http://patents.google.com/patent/US20190148572A1/en Crawling중입니다.
# Title :  74
# Abstract :  818
# http://patents.google.com/patent/US20160343896A1/en Crawling중입니다.
# Title :  100
# Abstract :  883
# http://patents.google.com/patent/KR101934434B1/en Crawling중입니다.
# Title :  87
# Abstract :  1371
# http://patents.google.com/patent/KR101367297B1/en Crawling중입니다.
# Title :  108
# Abstract :  1985
# http://patents.google.com/patent/KR102000793B1/en Crawling중입니다.
# Title :  82
# Abstract :  1206
# http://patents.google.com/patent/DE102012216740B4/en Crawling중입니다.
# Title :  197
# Abstract :  782
# http://patents.google.com/patent/CN104412393B/en Crawling중입니다.
# Title :  106
# Abstract :  1568
# http://patents.google.com/patent/US20150090317A1/en Crawling중입니다.
# Title :  110
# Abstract :  420
# http://patents.google.com/patent/EP2637220B1/en Crawling중입니다.
# Title :  75
# abstract 없음
# http://patents.google.com/patent/CN103579384B/en Crawling중입니다.
# Title :  78
# Abstract :  957
# http://patents.google.com/patent/DE102012217078B4/en Crawling중입니다.
# Title :  95
# Abstract :  2415
# http://patents.google.com/patent/KR101354928B1/en Crawling중입니다.
# Title :  123
# Abstract :  693
# http://patents.google.com/patent/CN104380475B/en Crawling중입니다.
# Title :  100
# Abstract :  1437
# http://patents.google.com/patent/DE102012214647A1/en Crawling중입니다.
# Title :  269
# Abstract :  775
# http://patents.google.com/patent/JP6292333B2/en Crawling중입니다.
# Title :  52
# abstract 없음
# http://patents.google.com/patent/KR20140052390A/en Crawling중입니다.
# Title :  96
# Abstract :  844
# http://patents.google.com/patent/KR101173429B1/en Crawling중입니다.
# Title :  87
# Abstract :  1124
# http://patents.google.com/patent/KR20140047760A/en Crawling중입니다.
# Title :  99
# Abstract :  762
# http://patents.google.com/patent/TWI500923B/en Crawling중입니다.
# Title :  98
# abstract 없음
# http://patents.google.com/patent/KR101403462B1/en Crawling중입니다.
# Title :  101
# Abstract :  985
# http://patents.google.com/patent/KR101995206B1/en Crawling중입니다.
# Title :  92
# Abstract :  1280
# http://patents.google.com/patent/JP2015514323A/en Crawling중입니다.
# Title :  167
# Abstract :  801
# http://patents.google.com/patent/WO2014073329A1/en Crawling중입니다.
# Title :  167
# Abstract :  1033
# http://patents.google.com/patent/KR101758197B1/en Crawling중입니다.
# Title :  89
# Abstract :  842
# http://patents.google.com/patent/JPWO2013157381A1/en Crawling중입니다.
# Title :  178
# Abstract :  432
# http://patents.google.com/patent/US20150255653A1/en Crawling중입니다.
# Title :  97
# Abstract :  749
# http://patents.google.com/patent/US9496440B2/en Crawling중입니다.
# Title :  57
# Abstract :  1109
# http://patents.google.com/patent/JP5956397B2/en Crawling중입니다.
# Title :  182
# abstract 없음
# http://patents.google.com/patent/TW201351676A/en Crawling중입니다.
# Title :  113
# Abstract :  834
# http://patents.google.com/patent/KR101172469B1/en Crawling중입니다.
# Title :  112
# Abstract :  880
# http://patents.google.com/patent/KR101797831B1/en Crawling중입니다.
# Title :  118
# Abstract :  742
# http://patents.google.com/patent/US20140170806A1/en Crawling중입니다.
# Title :  110
# Abstract :  930
# http://patents.google.com/patent/JP5980923B2/en Crawling중입니다.
# Title :  95
# abstract 없음
# http://patents.google.com/patent/US9991400B2/en Crawling중입니다.
# Title :  107
# Abstract :  819
# http://patents.google.com/patent/KR20150098667A/en Crawling중입니다.
# Title :  69
# Abstract :  460
# http://patents.google.com/patent/US9530903B2/en Crawling중입니다.
# Title :  134
# Abstract :  618
# http://patents.google.com/patent/JP6003904B2/en Crawling중입니다.
# Title :  114
# abstract 없음
# http://patents.google.com/patent/TWI452714B/en Crawling중입니다.
# Title :  90
# abstract 없음
# http://patents.google.com/patent/KR101369893B1/en Crawling중입니다.
# Title :  129
# Abstract :  984
# http://patents.google.com/patent/DE102012107472A1/en Crawling중입니다.
# Title :  266
# Abstract :  592
# http://patents.google.com/patent/JP5852234B2/en Crawling중입니다.
# Title :  91
# abstract 없음
# http://patents.google.com/patent/US20140060615A1/en Crawling중입니다.
# Title :  139
# Abstract :  634
# http://patents.google.com/patent/KR101398808B1/en Crawling중입니다.
# Title :  86
# Abstract :  667
# http://patents.google.com/patent/TWI575760B/en Crawling중입니다.
# Title :  118
# abstract 없음
# http://patents.google.com/patent/JP5584846B1/en Crawling중입니다.
# Title :  107
# Abstract :  1149
# http://patents.google.com/patent/KR101327536B1/en Crawling중입니다.
# Title :  166
# Abstract :  512
# http://patents.google.com/patent/WO2013108621A1/en Crawling중입니다.
# Title :  89
# Abstract :  1279
# http://patents.google.com/patent/US9293636B2/en Crawling중입니다.
# Title :  63
# Abstract :  634
# http://patents.google.com/patent/KR101382943B1/en Crawling중입니다.
# Title :  97
# Abstract :  381
# http://patents.google.com/patent/CN104247048B/en Crawling중입니다.
# Title :  88
# Abstract :  613
# http://patents.google.com/patent/US20160240712A1/en Crawling중입니다.
# Title :  102
# Abstract :  1084
# http://patents.google.com/patent/US20160013338A1/en Crawling중입니다.
# Title :  131
# Abstract :  950
# http://patents.google.com/patent/KR20140078779A/en Crawling중입니다.
# Title :  86
# Abstract :  957
# http://patents.google.com/patent/EP2662902A1/en Crawling중입니다.
# Title :  92
# Abstract :  343
# http://patents.google.com/patent/AU2013363569B2/en Crawling중입니다.
# Title :  106
# Abstract :  909
# http://patents.google.com/patent/AU2013237992A1/en Crawling중입니다.
# Title :  107
# Abstract :  183
# http://patents.google.com/patent/EP2892080A1/en Crawling중입니다.
# Title :  134
# Abstract :  672
# http://patents.google.com/patent/JP6037245B2/en Crawling중입니다.
# Title :  124
# abstract 없음
# http://patents.google.com/patent/US9147784B2/en Crawling중입니다.
# Title :  84
# Abstract :  776
# http://patents.google.com/patent/DE102012201284B4/en Crawling중입니다.
# Title :  95
# Abstract :  918
# http://patents.google.com/patent/JP5777798B2/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/KR101519703B1/en Crawling중입니다.
# Title :  77
# Abstract :  538
# http://patents.google.com/patent/KR101305682B1/en Crawling중입니다.
# Title :  97
# Abstract :  674
# http://patents.google.com/patent/CN104684657B/en Crawling중입니다.
# Title :  75
# Abstract :  1323
# http://patents.google.com/patent/CN103887354B/en Crawling중입니다.
# Title :  99
# Abstract :  940
# http://patents.google.com/patent/TWI617042B/en Crawling중입니다.
# Title :  106
# Abstract :  1094
# http://patents.google.com/patent/TWI482306B/en Crawling중입니다.
# Title :  128
# abstract 없음
# http://patents.google.com/patent/KR101358513B1/en Crawling중입니다.
# Title :  138
# Abstract :  792
# http://patents.google.com/patent/US9379261B2/en Crawling중입니다.
# Title :  81
# Abstract :  683
# http://patents.google.com/patent/JPWO2014014110A1/en Crawling중입니다.
# Title :  288
# Abstract :  415
# http://patents.google.com/patent/TW201334211A/en Crawling중입니다.
# Title :  99
# Abstract :  1049
# http://patents.google.com/patent/WO2014012442A1/en Crawling중입니다.
# Title :  99
# Abstract :  1271
# http://patents.google.com/patent/KR101349495B1/en Crawling중입니다.
# Title :  82
# Abstract :  912
# http://patents.google.com/patent/DE202012102494U1/en Crawling중입니다.
# Title :  101
# Abstract :  452
# http://patents.google.com/patent/TWI503999B/en Crawling중입니다.
# Title :  86
# abstract 없음
# http://patents.google.com/patent/JP2013168600A/en Crawling중입니다.
# Title :  114
# Abstract :  1033
# http://patents.google.com/patent/KR101865953B1/en Crawling중입니다.
# Title :  87
# Abstract :  1003
# http://patents.google.com/patent/JP2018027690A/en Crawling중입니다.
# Title :  205
# Abstract :  1171
# http://patents.google.com/patent/JP6224730B2/en Crawling중입니다.
# Title :  95
# abstract 없음
# http://patents.google.com/patent/JP6350278B2/en Crawling중입니다.
# Title :  128
# abstract 없음
# http://patents.google.com/patent/WO2014012436A1/en Crawling중입니다.
# Title :  102
# Abstract :  1001
# http://patents.google.com/patent/TWI509827B/en Crawling중입니다.
# Title :  95
# abstract 없음
# http://patents.google.com/patent/JP6295953B2/en Crawling중입니다.
# Title :  108
# abstract 없음
# http://patents.google.com/patent/KR101449942B1/en Crawling중입니다.
# Title :  158
# Abstract :  993
# http://patents.google.com/patent/CN104428901B/en Crawling중입니다.
# Title :  85
# Abstract :  774
# http://patents.google.com/patent/JP6226294B2/en Crawling중입니다.
# Title :  92
# abstract 없음
# http://patents.google.com/patent/KR101358561B1/en Crawling중입니다.
# Title :  90
# Abstract :  935
# http://patents.google.com/patent/US9825196B2/en Crawling중입니다.
# Title :  122
# Abstract :  579
# http://patents.google.com/patent/JP6008026B2/en Crawling중입니다.
# Title :  85
# abstract 없음
# http://patents.google.com/patent/KR101700728B1/en Crawling중입니다.
# Title :  89
# Abstract :  669
# http://patents.google.com/patent/CN103545385A/en Crawling중입니다.
# Title :  112
# Abstract :  1283
# http://patents.google.com/patent/KR101441975B1/en Crawling중입니다.
# Title :  110
# Abstract :  966
# http://patents.google.com/patent/EP2860768B1/en Crawling중입니다.
# Title :  114
# abstract 없음
# http://patents.google.com/patent/DE102013102574A1/en Crawling중입니다.
# Title :  264
# Abstract :  579
# http://patents.google.com/patent/WO2014073328A1/en Crawling중입니다.
# Title :  167
# Abstract :  1046
# http://patents.google.com/patent/KR102083249B1/en Crawling중입니다.
